# %%
import matplotlib.pyplot as plt
import logging
import sys
import numpy as np

logging.basicConfig(stream=sys.stdout)
for code in ["ngmix", "metadetect"]:
    logging.getLogger(code).setLevel(logging.DEBUG)

# %matplotlib inline

# %%
from test_shear_meas import make_sim, run_sim, meas_m_c_cancel

# %%
mbobs = make_sim(seed=10, g1=0.0, g2=0.0)

fig, axs = plt.subplots(figsize=(8, 8))
axs.imshow(np.arcsinh(mbobs[0][0].image * np.sqrt(mbobs[0][0].weight)), cmap='viridis')
axs.grid(False)

# %%
pres, mres = run_sim(10, 12)
# Out:
# DEBUG:metadetect.detect:box sizes: [32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32
#  32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32 32
#  32 32]
# DEBUG:metadetect.detect:minmax: 32 32
# DEBUG:metadetect.fitting:        wmom s2n: 687.206 Trat: 1.49972
# DEBUG:metadetect.fitting:        wmom s2n: 689.728 Trat: 1.49787
# DEBUG:metadetect.fitting:        wmom s2n: 688.478 Trat: 1.4969
# DEBUG:metadetect.fitting:        wmom s2n: 687.87 Trat: 1.49656
# DEBUG:metadetect.fitting:        wmom s2n: 706.147 Trat: 1.58247
# DEBUG:metadetect.fitting:        wmom s2n: 705.465 Trat: 1.59459
# DEBUG:metadetect.fitting:        wmom s2n: 687.277 Trat: 1.50552
# DEBUG:metadetect.fitting:        wmom s2n: 688.053 Trat: 1.49927
# DEBUG:metadetect.fitting:        wmom s2n: 687.432 Trat: 1.50023
# DEBUG:metadetect.fitting:        wmom s2n: 688.515 Trat: 1.50168
# DEBUG:metadetect.fitting:        wmom s2n: 687.976 Trat: 1.50473
# ...

# %%
meas_m_c_cancel(pres, mres)
# Out:
# (0.020990446868096146, -0.01624350836132912)
